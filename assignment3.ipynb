# %% [markdown]
# <b>Write a Pandas program to read a csv file from a specified source and print the
# first 5 rows.</b>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("diamonds.csv")
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %% [markdown]
# <b>2. Write a Pandas program to read a dataset from diamonds DataFrame and
# modify the default columns values and print the first 6 rows.</b>

# %%
df.head(6)
# Out:
#    Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0           1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1           2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2           3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3           4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4           5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 5           6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94
#
#       y     z
# 0  3.98  2.43
# 1  3.84  2.31
# 2  4.07  2.31
# 3  4.23  2.63
# 4  4.35  2.75
# 5  3.96  2.48

# %% [markdown]
# <b>3 Write a Pandas program to select a series from diamonds DataFrame. Print
# the content of the series</b>

# %%
df.iloc[:,0]
# Out:
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
#          ...
# 53935    53936
# 53936    53937
# 53937    53938
# 53938    53939
# 53939    53940
# Name: Unnamed: 0, Length: 53940, dtype: int64

# %% [markdown]
# <b>Write a Pandas program to create a new 'Quality -color' Series (use bracket
# notation to define the Series name) of the diamonds DataFrame.</b>

# %%
df['Quality-color'] = df['cut'] + '_' + df['color']
print("4. DataFrame after adding the new 'Quality-color' column:")
print(df[['cut', 'color', 'Quality-color']].head())
# Out:
# 4. DataFrame after adding the new 'Quality-color' column:
#        cut color Quality-color
# 0    Ideal     E       Ideal_E
# 1  Premium     E     Premium_E
# 2     Good     E        Good_E
# 3  Premium     I     Premium_I
# 4     Good     J        Good_J

# %% [markdown]
# <b>Write a Pandas program to find the number of rows and columns and data
# type of each column of diamonds Dataframe.</b>

# %%
df.shape
# Out:
# (53940, 12)

# %% [markdown]
# <b>6. Write a Pandas program to summarize only 'object' columns of the diamonds
# Dataframe. </b>

# %%
df.select_dtypes(include='object').describe()
# Out:
#           cut  color clarity Quality-color
# count   53940  53940   53940         53940
# unique      5      7       8            35
# top     Ideal      G     SI1       Ideal_G
# freq    21551  11292   13065          4884

# %% [markdown]
# 7. Write a Pandas program to rename two of the columns of the diamonds
# Dataframe.

# %%
df.rename(columns={'cut':'Cut','color':"Color"} ,inplace=True)
df
# Out:
#        Unnamed: 0  carat        Cut Color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z Quality-color
# ...

# %% [markdown]
# 8. Write a Pandas program to rename all of the columns of the diamonds
# Dataframe.

# %%
df.columns = ['ID', 'Carat', 'Quality', 'Color', 'Clarity','Depth', 'Table', 'Cost', 'X', 'Y', 'Z', 'Quality-Color']

df.head(6)
# Out:
#    ID  Carat    Quality Color Clarity  Depth  Table  Cost     X     Y     Z  \
# 0   1   0.23      Ideal     E     SI2   61.5   55.0   326  3.95  3.98  2.43
# 1   2   0.21    Premium     E     SI1   59.8   61.0   326  3.89  3.84  2.31
# 2   3   0.23       Good     E     VS1   56.9   65.0   327  4.05  4.07  2.31
# 3   4   0.29    Premium     I     VS2   62.4   58.0   334  4.20  4.23  2.63
# 4   5   0.31       Good     J     SI2   63.3   58.0   335  4.34  4.35  2.75
# 5   6   0.24  Very Good     J    VVS2   62.8   57.0   336  3.94  3.96  2.48
#
#   Quality-Color
# 0       Ideal_E
# 1     Premium_E
# 2        Good_E
# 3     Premium_I
# 4        Good_J
# 5   Very Good_J

# %% [markdown]
# 9. Write a Pandas program to remove the second column of the diamonds
# Dataframe.

# %%
df.drop(columns=df.columns[1], axis=1, inplace=True)
df.head(6)
# Out:
#    ID    Quality Color Clarity  Depth  Table  Cost     X     Y     Z  \
# 0   1      Ideal     E     SI2   61.5   55.0   326  3.95  3.98  2.43
# 1   2    Premium     E     SI1   59.8   61.0   326  3.89  3.84  2.31
# 2   3       Good     E     VS1   56.9   65.0   327  4.05  4.07  2.31
# 3   4    Premium     I     VS2   62.4   58.0   334  4.20  4.23  2.63
# 4   5       Good     J     SI2   63.3   58.0   335  4.34  4.35  2.75
# 5   6  Very Good     J    VVS2   62.8   57.0   336  3.94  3.96  2.48
#
#   Quality-Color
# 0       Ideal_E
# 1     Premium_E
# 2        Good_E
# 3     Premium_I
# 4        Good_J
# 5   Very Good_J

# %% [markdown]
# 10. Write a Pandas program to remove multiple columns at once of the diamonds
# Dataframe.

# %%
df.drop(columns=['X', 'Y', 'Z'], inplace=True)
df.head(6)
# Out:
#    ID    Quality Color Clarity  Depth  Table  Cost Quality-Color
# 0   1      Ideal     E     SI2   61.5   55.0   326       Ideal_E
# 1   2    Premium     E     SI1   59.8   61.0   326     Premium_E
# 2   3       Good     E     VS1   56.9   65.0   327        Good_E
# 3   4    Premium     I     VS2   62.4   58.0   334     Premium_I
# 4   5       Good     J     SI2   63.3   58.0   335        Good_J
# 5   6  Very Good     J    VVS2   62.8   57.0   336   Very Good_J

# %% [markdown]
# 11. Write a Pandas program to remove multiple rows at once (axis=0 refers to
# rows) from diamonds dataframe

# %%
df.drop(index=[0,1,2,3,4,5], axis=0, inplace=True)
df.head(6)
# Out:
#     ID    Quality Color Clarity  Depth  Table  Cost Quality-Color
# 6    7  Very Good     I    VVS1   62.3   57.0   336   Very Good_I
# 7    8  Very Good     H     SI1   61.9   55.0   337   Very Good_H
# 8    9       Fair     E     VS2   65.1   61.0   337        Fair_E
# 9   10  Very Good     H     VS1   59.4   61.0   338   Very Good_H
# 10  11       Good     J     SI1   64.0   55.0   339        Good_J
# 11  12      Ideal     J     VS1   62.8   56.0   340       Ideal_J

# %% [markdown]
# 12. Write a Pandas program to sort the 'cut' Series in ascending order (returns a
# Series) of diamonds Dataframe.

# %%
df = pd.read_csv('diamonds.csv')
#data_diamonds.head()
df['cut'].sort_values(ascending=True)
# Out:
# 3850          Fair
# 51464         Fair
# 51466         Fair
# 10237         Fair
# 10760         Fair
#            ...
# 7402     Very Good
# 43101    Very Good
# 16893    Very Good
# 16898    Very Good
# 21164    Very Good
# Name: cut, Length: 53940, dtype: object

# %% [markdown]
# 13. Write a Pandas program to sort the 'price' Series in descending order (returns
# a Series) of diamonds Dataframe

# %%
df["price"].sort_values(ascending=False)
# Out:
# 27749    18823
# 27748    18818
# 27747    18806
# 27746    18804
# 27745    18803
#          ...
# 4          335
# 3          334
# 2          327
# 1          326
# 0          326
# Name: price, Length: 53940, dtype: int64

# %% [markdown]
# 14. Write a Pandas program to sort the entire diamonds DataFrame by the 'carat'
# Series in ascending and descending order.

# %%
print("Assending : \n ", df.sort_values(by = "carat", ascending = True))
print("Decending : \n ", df.sort_values(by = "carat", ascending = False))
# Out:
# Assending :
#          Unnamed: 0  carat        cut color clarity  depth  table  price      x  \
# 14             15   0.20    Premium     E     SI2   60.2   62.0    345   3.79
# 31598       31599   0.20  Very Good     E     VS2   63.4   59.0    367   3.74
# 31600       31601   0.20    Premium     D     VS2   62.3   60.0    367   3.73
# 31591       31592   0.20    Premium     E     VS2   59.8   62.0    367   3.79
# 31592       31593   0.20    Premium     E     VS2   59.0   60.0    367   3.81
# ...           ...    ...        ...   ...     ...    ...    ...    ...    ...
# 25999       26000   4.01    Premium     J      I1   62.5   62.0  15223  10.02
# 25998       25999   4.01    Premium     I      I1   61.0   61.0  15223  10.14
# 27130       27131   4.13       Fair     H      I1   64.8   61.0  17329  10.00
# 27630       27631   4.50       Fair     J      I1   65.8   58.0  18531  10.23
# 27415       27416   5.01       Fair     J      I1   65.5   59.0  18018  10.74
#
# ...

# %% [markdown]
# 15. Write a Pandas program to filter the DataFrame rows to only show carat
# weight at least 0.3

# %%
df[df['carat'] > 0.3]
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 13             14   0.31      Ideal     J     SI2   62.2   54.0    344  4.35
# 15             16   0.32    Premium     E      I1   60.9   58.0    345  4.38
# 23             24   0.31  Very Good     J     SI1   59.4   62.0    353  4.39
# 24             25   0.31  Very Good     J     SI1   58.1   62.0    353  4.44
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 4      4.35  2.75
# ...

# %% [markdown]
# <b>16. Write a Pandas program to convert a python list to pandas series</b>

# %%
lst = [1,2,34,43,5,6]
pd_series= pd.Series(lst)
pd_series
# Out:
# 0     1
# 1     2
# 2    34
# 3    43
# 4     5
# 5     6
# dtype: int64

# %% [markdown]
# <b>17. Write a Pandas program to find the details of the diamonds where length>5,
# width>5 and depth>5.</b>

# %%
df[(df['x'] > 5) & (df['y'] > 5) & (df['z'] > 5)]
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 11778       11779   1.83       Fair     J      I1   70.0   58.0   5083  7.34
# 13002       13003   2.14       Fair     J      I1   69.4   57.0   5405  7.74
# 13118       13119   2.15       Fair     J      I1   65.5   57.0   5430  8.01
# 13562       13563   1.96       Fair     F      I1   66.6   60.0   5554  7.59
# 13757       13758   2.22       Fair     J      I1   66.7   56.0   5607  8.04
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 27748       27749   2.00  Very Good     G     SI1   63.5   56.0  18818  7.90
# 27749       27750   2.29    Premium     I     VS2   60.8   60.0  18823  8.50
# 48410       48411   0.51  Very Good     E     VS1   61.8   54.7   1970  5.12
# 49189       49190   0.51      Ideal     E     VS1   61.8   55.0   2075  5.15
# 49905       49906   0.50  Very Good     G    VVS1   63.7   58.0   2180  5.01
#
#            y      z
# 11778   7.28   5.12
# ...

# %% [markdown]
# <b>18. Write a Pandas program to find the diamonds that are either Premium or
# Ideal. </b>

# %%
df[(df['cut'] == 'Premium') | (df['cut'] == 'Ideal')]
# Out:
#        Unnamed: 0  carat      cut color clarity  depth  table  price     x  \
# 0               1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21  Premium     E     SI1   59.8   61.0    326  3.89
# 3               4   0.29  Premium     I     VS2   62.4   58.0    334  4.20
# 11             12   0.23    Ideal     J     VS1   62.8   56.0    340  3.93
# 12             13   0.22  Premium     F     SI1   60.4   61.0    342  3.88
# ...           ...    ...      ...   ...     ...    ...    ...    ...   ...
# 53931       53932   0.71  Premium     F     SI1   59.8   62.0   2756  5.74
# 53934       53935   0.72  Premium     D     SI1   62.7   59.0   2757  5.69
# 53935       53936   0.72    Ideal     D     SI1   60.8   57.0   2757  5.75
# 53938       53939   0.86  Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75    Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# 1      3.84  2.31
# ...

# %% [markdown]
# <b>19. Write a Pandas program to find the diamonds that are with a Fair or Good or
# Premium.</b>

# %%
df[(df['cut'] == "Fair" ) | (df['cut'] == "Good")]
# Out:
#        Unnamed: 0  carat   cut color clarity  depth  table  price     x     y  \
# 2               3   0.23  Good     E     VS1   56.9   65.0    327  4.05  4.07
# 4               5   0.31  Good     J     SI2   63.3   58.0    335  4.34  4.35
# 8               9   0.22  Fair     E     VS2   65.1   61.0    337  3.87  3.78
# 10             11   0.30  Good     J     SI1   64.0   55.0    339  4.25  4.28
# 17             18   0.30  Good     J     SI1   63.4   54.0    351  4.23  4.29
# ...           ...    ...   ...   ...     ...    ...    ...    ...   ...   ...
# 53913       53914   0.80  Good     G     VS2   64.2   58.0   2753  5.84  5.81
# 53914       53915   0.84  Good     I     VS1   63.7   59.0   2753  5.94  5.90
# 53916       53917   0.74  Good     D     SI1   63.1   59.0   2753  5.71  5.74
# 53927       53928   0.79  Good     F     SI1   58.1   59.0   2756  6.06  6.13
# 53936       53937   0.72  Good     D     SI1   63.1   55.0   2757  5.69  5.75
#
#           z
# 2      2.31
# ...

# %% [markdown]
# <b>20. Write a Pandas program to display all column labels of diamonds DataFrame.</b>

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'carat', 'cut', 'color', 'clarity', 'depth', 'table',
#        'price', 'x', 'y', 'z'],
#       dtype='object')

# %% [markdown]
# <b>21. Write a Pandas program to read only a subset of 3 rows from diamonds
# DataFrame.</b>

# %%
start = np.random.randint(0,len(df))
df.iloc[start:start+3]
# Out:
#        Unnamed: 0  carat      cut color clarity  depth  table  price     x  \
# 38854       38855    0.4  Premium     G    VVS2   62.5   60.0   1050  4.70
# 38855       38856    0.4    Ideal     G    VVS2   62.4   56.0   1050  4.74
# 38856       38857    0.4  Premium     G    VVS2   62.7   59.0   1050  4.72
#
#           y     z
# 38854  4.65  2.92
# 38855  4.72  2.95
# 38856  4.69  2.95

# %% [markdown]
# <b>22. Write a Pandas program to iterate through diamonds DataFrame.</b>

# %%
for index, row in df.iterrows():
    print(f"Index: {index}, Cut: {row['cut']}, Price: {row['price']}")
# Out:
# Index: 0, Cut: Ideal, Price: 326
# Index: 1, Cut: Premium, Price: 326
# Index: 2, Cut: Good, Price: 327
# Index: 3, Cut: Premium, Price: 334
# Index: 4, Cut: Good, Price: 335
# Index: 5, Cut: Very Good, Price: 336
# Index: 6, Cut: Very Good, Price: 336
# Index: 7, Cut: Very Good, Price: 337
# Index: 8, Cut: Fair, Price: 337
# Index: 9, Cut: Very Good, Price: 338
# Index: 10, Cut: Good, Price: 339
# Index: 11, Cut: Ideal, Price: 340
# Index: 12, Cut: Premium, Price: 342
# Index: 13, Cut: Ideal, Price: 344
# Index: 14, Cut: Premium, Price: 345
# Index: 15, Cut: Premium, Price: 345
# Index: 16, Cut: Ideal, Price: 348
# Index: 17, Cut: Good, Price: 351
# Index: 18, Cut: Good, Price: 351
# Index: 19, Cut: Very Good, Price: 351
# Index: 20, Cut: Good, Price: 351
# Index: 21, Cut: Very Good, Price: 352
# Index: 22, Cut: Very Good, Price: 353
# Index: 23, Cut: Very Good, Price: 353
# Index: 24, Cut: Very Good, Price: 353
# Index: 25, Cut: Very Good, Price: 354
# ...

# %% [markdown]
# <b>23. Write a Pandas program to drop all non-numeric columns from diamonds
# DataFrame.</b>

# %%
#data_diamonds.select_dtypes(include=['number'])
df.drop(columns=df.select_dtypes(exclude=['number']).columns)
# Out:
#        Unnamed: 0  carat  depth  table  price     x     y     z
# 0               1   0.23   61.5   55.0    326  3.95  3.98  2.43
# 1               2   0.21   59.8   61.0    326  3.89  3.84  2.31
# 2               3   0.23   56.9   65.0    327  4.05  4.07  2.31
# 3               4   0.29   62.4   58.0    334  4.20  4.23  2.63
# 4               5   0.31   63.3   58.0    335  4.34  4.35  2.75
# ...           ...    ...    ...    ...    ...   ...   ...   ...
# 53935       53936   0.72   60.8   57.0   2757  5.75  5.76  3.50
# 53936       53937   0.72   63.1   55.0   2757  5.69  5.75  3.61
# 53937       53938   0.70   62.8   60.0   2757  5.66  5.68  3.56
# 53938       53939   0.86   61.0   58.0   2757  6.15  6.12  3.74
# 53939       53940   0.75   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 8 columns]

# %% [markdown]
# <b>24. Write a Pandas program to include only numeric columns in the diamonds
# DataFrame.</b>

# %%
df.select_dtypes(include=['number'])
# Out:
#        Unnamed: 0  carat  depth  table  price     x     y     z
# 0               1   0.23   61.5   55.0    326  3.95  3.98  2.43
# 1               2   0.21   59.8   61.0    326  3.89  3.84  2.31
# 2               3   0.23   56.9   65.0    327  4.05  4.07  2.31
# 3               4   0.29   62.4   58.0    334  4.20  4.23  2.63
# 4               5   0.31   63.3   58.0    335  4.34  4.35  2.75
# ...           ...    ...    ...    ...    ...   ...   ...   ...
# 53935       53936   0.72   60.8   57.0   2757  5.75  5.76  3.50
# 53936       53937   0.72   63.1   55.0   2757  5.69  5.75  3.61
# 53937       53938   0.70   62.8   60.0   2757  5.66  5.68  3.56
# 53938       53939   0.86   61.0   58.0   2757  6.15  6.12  3.74
# 53939       53940   0.75   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 8 columns]

# %% [markdown]
# <b>25. Write a Pandas program to pass a list of data types to only describe certain
# types of diamonds DataFrame. </b>

# %%
df.describe(include=['number'])
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# ...

# %% [markdown]
# <b>26. Write a Pandas program to calculate the mean of each numeric column of
# diamonds DataFrame.</b>

# %%
df.mean(numeric_only=True)
# Out:
# Unnamed: 0    26970.500000
# carat             0.797940
# depth            61.749405
# table            57.457184
# price          3932.799722
# x                 5.731157
# y                 5.734526
# z                 3.538734
# dtype: float64

# %% [markdown]
# <b>27. Write a Pandas program to calculate the mean of each row of diamonds
# DataFrame.</b>

# %%
# data_diamonds['mean'] = data_diamonds.mean(axis= 1, numeric_only=True)
# data_diamonds
df.mean(axis= 1, numeric_only=True)
# Out:
# 0          56.76125
# 1          57.38125
# 2          57.82000
# 3          58.71875
# 4          59.13125
#             ...
# 53935    7103.31625
# 53936    7103.48375
# 53937    7104.17500
# 53938    7103.98375
# 53939    7103.78625
# Length: 53940, dtype: float64

# %% [markdown]
# <b>28. Write a Pandas program to calculate the mean of price for each cut of
# diamonds DataFrame</b>

# %%
mean_price_by_cut = df.groupby('cut')['price'].mean()
mean_price_by_cut
# Out:
# cut
# Fair         4358.757764
# Good         3928.864452
# Ideal        3457.541970
# Premium      4584.257704
# Very Good    3981.759891
# Name: price, dtype: float64

# %% [markdown]
# <b>29. Write a Pandas program to calculate count, minimum, maximum price for
# each cut of diamonds DataFrame.</b>

# %%
mean_price_by_cut = df.groupby('cut')['price'].mean()
min_price_by_cut =df.groupby('cut')['price'].min()
max_price_by_cut = df.groupby('cut')['price'].max()
print('------------min----------')
print(min_price_by_cut)
print()
print("------------max-----------")
print(max_price_by_cut)
print()
print("------------mean-----------")
print(mean_price_by_cut)
# Out:
# ------------min----------
# cut
# Fair         337
# Good         327
# Ideal        326
# Premium      326
# Very Good    336
# Name: price, dtype: int64
#
# ------------max-----------
# cut
# Fair         18574
# Good         18788
# Ideal        18806
# Premium      18823
# Very Good    18818
# Name: price, dtype: int64
#
# ------------mean-----------
# cut
# Fair         4358.757764
# Good         3928.864452
# Ideal        3457.541970
# Premium      4584.257704
# Very Good    3981.759891
# Name: price, dtype: float64

# %% [markdown]
# <b>30. Write a Pandas program to create a side-by-side bar plot of the diamonds
# DataFrame.</b>

# %%
import matplotlib.pylab as plt
import seaborn as sns
plt.figure(figsize=(12, 6))
sns.barplot(x="cut", y="price", hue="clarity", data=df,errorbar=None)

plt.title("Average Diamond Price by Cut and Clarity")
plt.xlabel("Cut")
plt.ylabel("Average Price")
plt.legend(title="Clarity", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# <b>31. Write a Pandas program to count how many times each value in cut series of
# diamonds DataFrame occurs.</b>

# %%
cut_counts = df['cut'].value_counts()
cut_counts
# Out:
# cut
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: count, dtype: int64

# %% [markdown]
# <b>32. Write a Pandas program to display percentages of each value of cut series
# occurs in diamonds DataFrame.</b>

# %%
cut_percentages = df['cut'].value_counts(normalize=True) * 100
cut_percentages
# Out:
# cut
# Ideal        39.953652
# Premium      25.567297
# Very Good    22.398962
# Good          9.095291
# Fair          2.984798
# Name: proportion, dtype: float64

# %% [markdown]
# <b>33. Write a Pandas program to display the unique values in cut series of
# diamonds DataFrame.</b>

# %%
cunique_cuts = df['cut'].unique()
cunique_cuts
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %% [markdown]
# <b>34. Write a Pandas program to count the number of unique values in cut series of
# diamonds DataFrame.</b>

# %%
unique_cut_count = df['cut'].nunique()
unique_cut_count
# Out:
# 5

# %% [markdown]
# <b>35. Write a Pandas program to compute a cross-tabulation of two Series in
# diamonds DataFrame.</b>

# %%
cut_clarity_crosstab = pd.crosstab(df['cut'], df['clarity'])
cut_clarity_crosstab
# Out:
# clarity     I1    IF   SI1   SI2   VS1   VS2  VVS1  VVS2
# cut
# Fair       210     9   408   466   170   261    17    69
# Good        96    71  1560  1081   648   978   186   286
# Ideal      146  1212  4282  2598  3589  5071  2047  2606
# Premium    205   230  3575  2949  1989  3357   616   870
# Very Good   84   268  3240  2100  1775  2591   789  1235

# %% [markdown]
# <b>36. Write a Pandas program to calculate various summary statistics of cut series
# of diamonds DataFrame.</b>

# %%
df['cut'].describe()
# Out:
# count     53940
# unique        5
# top       Ideal
# freq      21551
# Name: cut, dtype: object

# %% [markdown]
# <b>37. Write a Pandas program to create a histogram of the 'carat' Series
# (distribution of a numerical variable) of diamonds DataFrame.</b>

# %%
df['carat'].plot(kind='hist', bins=30, color='pink', edgecolor='black')
plt.title("Distribution of Diamond Carat")
plt.xlabel("Carat")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %% [markdown]
# <b>38. Write a Pandas program to create a bar plot of the 'value_counts' for the 'cut'
# series of diamonds DataFrame.</b>

# %%
cut_counts = df['cut'].value_counts()
cut_counts.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title("Frequency of Diamond Cuts")
plt.xlabel("Cut Type")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# <b>39. Write a Pandas program to create a DataFrame of booleans (True if missing,
# False if not missing) from diamonds DataFrame.</b>

# %%
missing_values_df = df.isnull()
missing_values_df
# Out:
#        Unnamed: 0  carat    cut  color  clarity  depth  table  price      x  \
# 0           False  False  False  False    False  False  False  False  False
# 1           False  False  False  False    False  False  False  False  False
# 2           False  False  False  False    False  False  False  False  False
# 3           False  False  False  False    False  False  False  False  False
# 4           False  False  False  False    False  False  False  False  False
# ...           ...    ...    ...    ...      ...    ...    ...    ...    ...
# 53935       False  False  False  False    False  False  False  False  False
# 53936       False  False  False  False    False  False  False  False  False
# 53937       False  False  False  False    False  False  False  False  False
# 53938       False  False  False  False    False  False  False  False  False
# 53939       False  False  False  False    False  False  False  False  False
#
#            y      z
# 0      False  False
# ...

# %% [markdown]
# <b>40. Write a Pandas program to count the number of missing values in each
# Series of diamonds DataFrame.</b>

# %%
missing_counts = df.isnull().sum()
missing_counts
# Out:
# Unnamed: 0    0
# carat         0
# cut           0
# color         0
# clarity       0
# depth         0
# table         0
# price         0
# x             0
# y             0
# z             0
# dtype: int64

# %% [markdown]
# <b>41. Write a Pandas program to check the number of rows and columns and drop
# those row if 'any' values are missing in a row of diamonds DataFrame.</b>

# %%
rows, columns = df.shape
print(f"Original shape: {rows} rows, {columns} columns")

diamonds_cleaned = df.dropna(how='any')

new_rows, new_columns = diamonds_cleaned.shape
print(f"After dropping rows with missing values: {new_rows} rows, {new_columns} columns")
# Out:
# Original shape: 53940 rows, 11 columns
# After dropping rows with missing values: 53940 rows, 11 columns

# %% [markdown]
# <b>42. Write a Pandas program to drop a row if any or all values in a row are
# missing of diamonds DataFrame on two specific columns.</b>

# %%
print("all")
df.dropna(subset=['cut', 'color'], how='all', inplace=True)
print(df)
print("<-any->")
df.dropna(subset=['cut', 'color'], how='any', inplace=True)
print(df)
# Out:
# all
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# ...           ...    ...        ...   ...     ...    ...    ...    ...   ...
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 0      3.98  2.43
# ...

# %% [markdown]
# <b>43. Write a Pandas program to set an existing column as the index of diamonds
# DataFrame</b>

# %%
df.set_index('depth', inplace=True)
df
# Out:
#        Unnamed: 0  carat        cut color clarity  table  price     x     y  \
# depth
# 61.5            1   0.23      Ideal     E     SI2   55.0    326  3.95  3.98
# 59.8            2   0.21    Premium     E     SI1   61.0    326  3.89  3.84
# 56.9            3   0.23       Good     E     VS1   65.0    327  4.05  4.07
# 62.4            4   0.29    Premium     I     VS2   58.0    334  4.20  4.23
# 63.3            5   0.31       Good     J     SI2   58.0    335  4.34  4.35
# ...           ...    ...        ...   ...     ...    ...    ...   ...   ...
# 60.8        53936   0.72      Ideal     D     SI1   57.0   2757  5.75  5.76
# 63.1        53937   0.72       Good     D     SI1   55.0   2757  5.69  5.75
# 62.8        53938   0.70  Very Good     D     SI1   60.0   2757  5.66  5.68
# 61.0        53939   0.86    Premium     H     SI2   58.0   2757  6.15  6.12
# 62.2        53940   0.75      Ideal     D     SI2   55.0   2757  5.83  5.87
#
#           z
# depth
# 61.5   2.43
# 59.8   2.31
# ...

# %% [markdown]
# <b>44. Write a Pandas program to set an existing column as the index of diamonds
# DataFrame and restore the index name, and move the index back to a column.</b>

# %%
df.set_index('cut', inplace=True)
df.index.name = 'cut'
df.reset_index(inplace=True)
df
# Out:
#              cut  Unnamed: 0  carat color clarity  table  price     x     y  \
# 0          Ideal           1   0.23     E     SI2   55.0    326  3.95  3.98
# 1        Premium           2   0.21     E     SI1   61.0    326  3.89  3.84
# 2           Good           3   0.23     E     VS1   65.0    327  4.05  4.07
# 3        Premium           4   0.29     I     VS2   58.0    334  4.20  4.23
# 4           Good           5   0.31     J     SI2   58.0    335  4.34  4.35
# ...          ...         ...    ...   ...     ...    ...    ...   ...   ...
# 53935      Ideal       53936   0.72     D     SI1   57.0   2757  5.75  5.76
# 53936       Good       53937   0.72     D     SI1   55.0   2757  5.69  5.75
# 53937  Very Good       53938   0.70     D     SI1   60.0   2757  5.66  5.68
# 53938    Premium       53939   0.86     H     SI2   58.0   2757  6.15  6.12
# 53939      Ideal       53940   0.75     D     SI2   55.0   2757  5.83  5.87
#
#           z
# 0      2.43
# 1      2.31
# 2      2.31
# ...

# %% [markdown]
# <b>45. Write a Pandas program to access a specified Series index and the Series
# values of diamonds DataFrame.</b>

# %%
print(df['cut'].index)
print(df['cut'].values)
# Out:
# RangeIndex(start=0, stop=53940, step=1)
# ['Ideal' 'Premium' 'Good' ... 'Very Good' 'Premium' 'Ideal']

# %% [markdown]
# <b>46. Write a Pandas program to sort a Series by its values and index of diamonds
# DataFrame.</b>

# %%
df['price'].sort_values()
# Out:
# 0          326
# 1          326
# 2          327
# 3          334
# 4          335
#          ...
# 27745    18803
# 27746    18804
# 27747    18806
# 27748    18818
# 27749    18823
# Name: price, Length: 53940, dtype: int64

# %% [markdown]
# <b>47. Write a Pandas program to calculate the multiply of length, width and depth
# for each cut of diamonds DataFrame.</b>

# %%
df['volume'] = df['x'].astype(int) * df['y'].astype(int) * df['z'].astype(int)
volume_by_cut = df.groupby('cut')['volume'].agg(['sum', 'mean', 'count'])
print(volume_by_cut)
# Out:
#                sum        mean  count
# cut
# Fair        205012  127.336646   1610
# Good        504766  102.887485   4906
# Ideal      1813260   84.138091  21551
# Premium    1486774  107.807556  13791
# Very Good  1173679   97.142774  12082

# %% [markdown]
# <b>48. Write a Pandas program to concatenate the diamonds DataFrame with the
# 'color' Series.</b>

# %%
pd.concat([df, df['color']], axis=1)
# Out:
#              cut  Unnamed: 0  carat color clarity  table  price     x     y  \
# 0          Ideal           1   0.23     E     SI2   55.0    326  3.95  3.98
# 1        Premium           2   0.21     E     SI1   61.0    326  3.89  3.84
# 2           Good           3   0.23     E     VS1   65.0    327  4.05  4.07
# 3        Premium           4   0.29     I     VS2   58.0    334  4.20  4.23
# 4           Good           5   0.31     J     SI2   58.0    335  4.34  4.35
# ...          ...         ...    ...   ...     ...    ...    ...   ...   ...
# 53935      Ideal       53936   0.72     D     SI1   57.0   2757  5.75  5.76
# 53936       Good       53937   0.72     D     SI1   55.0   2757  5.69  5.75
# 53937  Very Good       53938   0.70     D     SI1   60.0   2757  5.66  5.68
# 53938    Premium       53939   0.86     H     SI2   58.0   2757  6.15  6.12
# 53939      Ideal       53940   0.75     D     SI2   55.0   2757  5.83  5.87
#
#           z  volume color
# 0      2.43      18     E
# ...

# %% [markdown]
# <b>49. Write a Pandas program to read specified rows and all columns of diamonds
# DataFrame.</b>

# %%
df.iloc[0:10,:]
# Out:
#          cut  Unnamed: 0  carat color clarity  table  price     x     y     z  \
# 0      Ideal           1   0.23     E     SI2   55.0    326  3.95  3.98  2.43
# 1    Premium           2   0.21     E     SI1   61.0    326  3.89  3.84  2.31
# 2       Good           3   0.23     E     VS1   65.0    327  4.05  4.07  2.31
# 3    Premium           4   0.29     I     VS2   58.0    334  4.20  4.23  2.63
# 4       Good           5   0.31     J     SI2   58.0    335  4.34  4.35  2.75
# 5  Very Good           6   0.24     J    VVS2   57.0    336  3.94  3.96  2.48
# 6  Very Good           7   0.24     I    VVS1   57.0    336  3.95  3.98  2.47
# 7  Very Good           8   0.26     H     SI1   55.0    337  4.07  4.11  2.53
# 8       Fair           9   0.22     E     VS2   61.0    337  3.87  3.78  2.49
# 9  Very Good          10   0.23     H     VS1   61.0    338  4.00  4.05  2.39
#
#    volume
# 0      18
# 1      18
# 2      32
# 3      32
# 4      32
# 5      18
# 6      18
# 7      32
# ...

# %% [markdown]
# <b>50. Write a Pandas program to read rows 0, 5, 7 and all columns of diamonds
# DataFrame.</b>

# %%
df.iloc[[0,5,7],:]
# Out:
#          cut  Unnamed: 0  carat color clarity  table  price     x     y     z  \
# 0      Ideal           1   0.23     E     SI2   55.0    326  3.95  3.98  2.43
# 5  Very Good           6   0.24     J    VVS2   57.0    336  3.94  3.96  2.48
# 7  Very Good           8   0.26     H     SI1   55.0    337  4.07  4.11  2.53
#
#    volume
# 0      18
# 5      18
# 7      32

# %% [markdown]
# <b>51. Write a Pandas program to read rows 2 through 5 and all columns of
# diamonds DataFrame.</b>

# %%
df.iloc[2:6,:]
# Out:
#          cut  Unnamed: 0  carat color clarity  table  price     x     y     z  \
# 2       Good           3   0.23     E     VS1   65.0    327  4.05  4.07  2.31
# 3    Premium           4   0.29     I     VS2   58.0    334  4.20  4.23  2.63
# 4       Good           5   0.31     J     SI2   58.0    335  4.34  4.35  2.75
# 5  Very Good           6   0.24     J    VVS2   57.0    336  3.94  3.96  2.48
#
#    volume
# 2      32
# 3      32
# 4      32
# 5      18

# %% [markdown]
# <b>52. Write a Pandas program to read rows 0 through 2 (inclusive), columns 'color'
# and 'price' of diamonds DataFrame.</b>

# %%
df.iloc[0:3,3]
# Out:
# 0    E
# 1    E
# 2    E
# Name: color, dtype: object

# %% [markdown]
# <b>53. Write a Pandas program to read rows 0 through 2 (inclusive), columns 'color'
# through 'price' (inclusive) of diamonds DataFrame.</b>

# %%
df.iloc[0:3,3:7]
# Out:
#   color clarity  table  price
# 0     E     SI2   55.0    326
# 1     E     SI1   61.0    326
# 2     E     VS1   65.0    327

# %% [markdown]
# <b>54. Write a Pandas program to read rows in which the 'cut' is 'Premium', column
# 'color' of diamonds DataFrame.</b>

# %%
df.loc[df['cut'] == 'Premium', 'color']
# Out:
# 1        E
# 3        I
# 12       F
# 14       E
# 15       E
#         ..
# 53928    E
# 53930    E
# 53931    F
# 53934    D
# 53938    H
# Name: color, Length: 13791, dtype: object

# %% [markdown]
# <b>55. Write a Pandas program to read rows in positions 0 and 1, columns in
# positions 0 and 3 of diamonds DataFrame.</b>

# %%
df.iloc[[0,1], [0,3]]
# Out:
#        cut color
# 0    Ideal     E
# 1  Premium     E

# %% [markdown]
# <b>56. Write a Pandas program to read rows in positions 0 through 4, columns in
# positions 1 through 4 of diamonds DataFrame.</b>

# %%
df.iloc[0:5, 1:5]
# Out:
#    Unnamed: 0  carat color clarity
# 0           1   0.23     E     SI2
# 1           2   0.21     E     SI1
# 2           3   0.23     E     VS1
# 3           4   0.29     I     VS2
# 4           5   0.31     J     SI2

# %% [markdown]
# <b>57. Write a Pandas program to read rows in positions 0 through 4 (exclusive) and
# all columns of diamonds DataFrame.</b>

# %%
df.iloc[0:4, :]
# Out:
#        cut  Unnamed: 0  carat color clarity  table  price     x     y     z  \
# 0    Ideal           1   0.23     E     SI2   55.0    326  3.95  3.98  2.43
# 1  Premium           2   0.21     E     SI1   61.0    326  3.89  3.84  2.31
# 2     Good           3   0.23     E     VS1   65.0    327  4.05  4.07  2.31
# 3  Premium           4   0.29     I     VS2   58.0    334  4.20  4.23  2.63
#
#    volume
# 0      18
# 1      18
# 2      32
# 3      32

# %% [markdown]
# <b>58. Write a Pandas program to read rows 2 through 5 (inclusive), columns in
# positions 0 through 2 (exclusive) of diamonds DataFrame.</b>

# %%
df.iloc[2:6,0:2]
# Out:
#          cut  Unnamed: 0
# 2       Good           3
# 3    Premium           4
# 4       Good           5
# 5  Very Good           6

# %% [markdown]
# <b>59. Write a Pandas program to print a concise summary of diamonds
# DataFrame.</b>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   cut         53940 non-null  object
#  1   Unnamed: 0  53940 non-null  int64
#  2   carat       53940 non-null  float64
#  3   color       53940 non-null  object
#  4   clarity     53940 non-null  object
#  5   table       53940 non-null  float64
#  6   price       53940 non-null  int64
#  7   x           53940 non-null  float64
#  8   y           53940 non-null  float64
#  9   z           53940 non-null  float64
#  10  volume      53940 non-null  int64
# dtypes: float64(5), int64(3), object(3)
# memory usage: 4.5+ MB

# %% [markdown]
# <b>60. Write a Pandas program to get the true memory usage by diamonds
# DataFrame.</b>

# %%
df.memory_usage(deep=True).sum().item()
# Out:
# 11942516

# %% [markdown]
# <b>61. Write a Pandas program to calculate the memory usage for each Series (in
# bytes) of diamonds DataFrame.</b>

# %%
df.memory_usage(deep=True)
# Out:
# Index             132
# cut           2982154
# Unnamed: 0     431520
# carat          431520
# color         2697000
# clarity       2811070
# table          431520
# price          431520
# x              431520
# y              431520
# z              431520
# volume         431520
# dtype: int64

# %% [markdown]
# <b>62. Write a Pandas program to get randomly sample rows from diamonds
# DataFrame.</b>

# %%
df.sample(10)
# Out:
#              cut  Unnamed: 0  carat color clarity  table  price     x     y  \
# 7994   Very Good        7995   0.92     D     SI2   58.0   4327  6.19  6.22
# 31666    Premium       31667   0.32     E     VS2   59.0    768  4.43  4.40
# 10631      Ideal       10632   1.15     H     SI2   57.0   4830  6.75  6.66
# 23144    Premium       23145   1.30     G    VVS1   60.0  11162  7.05  7.01
# 16210      Ideal       16211   1.02     F     VS2   56.0   6479  6.39  6.44
# 4860     Premium        4861   1.00     I     SI2   59.0   3712  6.34  6.41
# 14660  Very Good       14661   1.05     G     VS2   55.0   5917  6.50  6.56
# 32299      Ideal       32300   0.34     E     SI2   55.0    454  4.50  4.52
# 20903      Ideal       20904   1.06     F    VVS2   57.0   9118  6.54  6.50
# 40045       Good       40046   0.54     E     SI2   54.0   1112  5.18  5.12
#
#           z  volume
# 7994   3.82     108
# 31666  2.72      32
# 10631  4.16     144
# 23144  4.25     196
# 16210  4.02     144
# ...

# %% [markdown]
# <b>63. Write a Pandas program to get sample 75% of the diamonds DataFrame's
# rows without replacement and store the remaining 25% of the rows in another
# DataFrame.</b>

# %%
df.sample(frac=0.75, random_state=42)
# Out:
#              cut  Unnamed: 0  carat color clarity  table  price     x     y  \
# 1388       Ideal        1389   0.24     G    VVS1   56.0    559  3.97  4.00
# 50052  Very Good       50053   0.58     F    VVS2   57.0   2201  5.44  5.42
# 41645      Ideal       41646   0.40     E    VVS2   55.0   1238  4.76  4.74
# 42377    Premium       42378   0.43     E    VVS2   57.0   1304  4.92  4.89
# 17244      Ideal       17245   1.55     E     SI2   55.0   6901  7.44  7.37
# ...          ...         ...    ...   ...     ...    ...    ...   ...   ...
# 48565       Good       48566   0.50     G    VVS2   57.0   1991  4.97  5.05
# 12312      Ideal       12313   1.24     I     SI2   57.0   5221  6.87  6.92
# 18130    Premium       18131   1.51     H     SI2   62.0   7340  7.43  7.38
# 39846  Very Good       39847   0.51     F     SI2   56.0   1100  5.07  5.10
# 9114   Very Good        9115   1.02     I     VS2   59.0   4532  6.56  6.60
#
#           z  volume
# 1388   2.47      24
# ...

# %% [markdown]
# <b>64. Write a Pandas program to read the diamonds DataFrame and detect
# duplicate color.
# Note: duplicated () function returns boolean Series denoting duplicate rows,
# optionally only considering certain columns.</b>

# %%
df[df.duplicated(subset=['color'])]
# Out:
#              cut  Unnamed: 0  carat color clarity  table  price     x     y  \
# 1        Premium           2   0.21     E     SI1   61.0    326  3.89  3.84
# 2           Good           3   0.23     E     VS1   65.0    327  4.05  4.07
# 5      Very Good           6   0.24     J    VVS2   57.0    336  3.94  3.96
# 6      Very Good           7   0.24     I    VVS1   57.0    336  3.95  3.98
# 8           Fair           9   0.22     E     VS2   61.0    337  3.87  3.78
# ...          ...         ...    ...   ...     ...    ...    ...   ...   ...
# 53935      Ideal       53936   0.72     D     SI1   57.0   2757  5.75  5.76
# 53936       Good       53937   0.72     D     SI1   55.0   2757  5.69  5.75
# 53937  Very Good       53938   0.70     D     SI1   60.0   2757  5.66  5.68
# 53938    Premium       53939   0.86     H     SI2   58.0   2757  6.15  6.12
# 53939      Ideal       53940   0.75     D     SI2   55.0   2757  5.83  5.87
#
#           z  volume
# 1      2.31      18
# ...

# %% [markdown]
# <b>65. Write a Pandas program to count the duplicate rows of diamonds DataFrame.</b>

# %%
df.duplicated().sum().item()
# Out:
# 0
